# %% [markdown]
# # EE2405 Embedded System Lab Exam #2 Part 2
#
# **Please click on "Open in playground" at the upper-left corner to create a copy for you.**
#
# ---
#
# **Please fill in correct statements in the right of the codes to finish the scripts.**
# Data sample is generated with a quadratic function and we will train a regression model to fit the data.
# And we convert and interpret the trained model with a Tensorflow lite APIs.
#
# You can run the script again after you fill all the blank to check the outputs.
#
# ---
#
# The Method to Download the Jupyter Notebook:
# File > Download .ipynb

# %% [markdown]
# ## Import dependencies

# %%
# TensorFlow is an open source machine learning library
import tensorflow as tf
# Numpy is a math library
import numpy as np
# Matplotlib is a graphing library
import matplotlib.pyplot as plt
# math is Python's math library
import math

# %% [markdown]
# ## Generate Data

# %%
# We'll generate this many sample datapoints
############################################################
#@markdown Please fill in the number of samples (the sample should be large enough, but not too large for computation).
SAMPLES =  1000#@param {type:"number"}
############################################################


############################################################
#@markdown Please fill in your student id, which is the random seed.
student_id = 106061236 #@param {type:"number"}
np.random.seed(student_id)
############################################################

# Generate a uniformly distributed set of random numbers
# in the range from 0 to 10
x_values = np.random.uniform(low=0, high=10, size=SAMPLES)

# Shuffle the values to guarantee they're not in order
np.random.shuffle(x_values)

############################################################
#@markdown Please fill in the statement to generate `y_values` with a quadratic function `y = x^2-5x+1`?
script = "y_values = x_values*x_values - 5*x_values + 1" #@param {type:"string"}
exec(script)
############################################################

# Plot our data.
# The 'b.' argument tells the library to print blue dots.
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ## Add some noise

# %%
# Add a small random number to each y value
y_values += np.random.randn(*y_values.shape)

# Plot our data
plt.plot(x_values, y_values, 'b.')
plt.show()

# %% [markdown]
# ## Split our data

# %%
# We'll use 60% of our data for training and 20% for testing. The remaining 20%
# will be used for validation. Calculate the indices of each section.
TRAIN_SPLIT =  int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)

# Use np.split to chop our data into three parts.
# The second argument to np.split is an array of indices where the data will be
# split. We provide two indices, so the data will be divided into three chunks.
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# Double check that our splits add up correctly
assert (x_train.size + x_validate.size + x_test.size) ==  SAMPLES

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'y.', label="Validate")
plt.legend()
plt.show()

# %% [markdown]
# ## Design a model

# %%
# We'll use Keras to create a simple model architecture
from tensorflow.keras import layers
model = tf.keras.Sequential()

# First layer takes a scalar input and feeds it through 16 "neurons". The
# neurons decide whether to activate based on the 'relu' activation function.
model.add(layers.Dense(16, activation='relu', input_shape=(1,)))

# The new second layer may help the network learn more complex representations
model.add(layers.Dense(16, activation='relu'))

# Final layer is a single neuron, since we want to output a single value
model.add(layers.Dense(1))

# Compile the model using a standard optimizer and loss function for regression
model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# %% [markdown]
# ## Train the model

# %%
# Train the model on our training data while validating on our validation set
model.fit(x_train, y_train, epochs=1000, batch_size=16,
          validation_data=(x_validate, y_validate))

print("Done!")
# Out:
# Epoch 1/1000
# 38/38 [==============================] - 0s 6ms/step - loss: 240.9547 - mae: 10.6506 - val_loss: 255.6274 - val_mae: 11.3268
# Epoch 2/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 193.0981 - mae: 9.9365 - val_loss: 203.7647 - val_mae: 10.5578
# Epoch 3/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 159.6229 - mae: 9.5490 - val_loss: 166.5405 - val_mae: 10.0377
# Epoch 4/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 136.8890 - mae: 9.2748 - val_loss: 138.3182 - val_mae: 9.6477
# Epoch 5/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 123.2403 - mae: 9.2296 - val_loss: 123.6866 - val_mae: 9.4438
# Epoch 6/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 117.0886 - mae: 9.2311 - val_loss: 117.4780 - val_mae: 9.3294
# Epoch 7/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 113.7419 - mae: 9.2620 - val_loss: 114.7916 - val_mae: 9.2351
# Epoch 8/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 113.6896 - mae: 9.1544 - val_loss: 112.2427 - val_mae: 9.1507
# Epoch 9/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 110.5402 - mae: 9.0963 - val_loss: 110.3692 - val_mae: 9.0535
# Epoch 10/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 108.8184 - mae: 8.9730 - val_loss: 108.1172 - val_mae: 8.9578
# Epoch 11/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 107.4910 - mae: 8.8958 - val_loss: 105.7339 - val_mae: 8.8601
# Epoch 12/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 104.9153 - mae: 8.8001 - val_loss: 103.5586 - val_mae: 8.7551
# Epoch 13/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 103.4905 - mae: 8.7254 - val_loss: 102.2045 - val_mae: 8.6600
# Epoch 14/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 101.5591 - mae: 8.5951 - val_loss: 99.4335 - val_mae: 8.5591
# Epoch 15/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 99.3010 - mae: 8.5215 - val_loss: 98.1553 - val_mae: 8.4571
# Epoch 16/1000
# 38/38 [==============================] - 0s 2ms/step - loss:
1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0547 - mae: 0.8163 - val_loss: 1.1805 - val_mae: 0.9128
# Epoch 179/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0959 - mae: 0.8317 - val_loss: 1.1567 - val_mae: 0.8784
# Epoch 180/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0777 - mae: 0.8343 - val_loss: 1.1819 - val_mae: 0.8796
# Epoch 181/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0859 - mae: 0.8290 - val_loss: 1.2123 - val_mae: 0.9251
# Epoch 182/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0450 - mae: 0.8111 - val_loss: 1.1440 - val_mae: 0.8881
# Epoch 183/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0768 - mae: 0.8332 - val_loss: 1.3281 - val_mae: 0.9114
# Epoch 184/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0852 - mae: 0.8348 - val_loss: 1.1620 - val_mae: 0.9024
# Epoch 185/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0856 - mae: 0.8302 - val_loss: 1.3245 - val_mae: 0.9091
# Epoch 186/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0761 - mae: 0.8206 - val_loss: 1.2299 - val_mae: 0.9153
# Epoch 187/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0955 - mae: 0.8359 - val_loss: 1.2768 - val_mae: 0.8972
# Epoch 188/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1052 - mae: 0.8378 - val_loss: 1.1442 - val_mae: 0.8977
# Epoch 189/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0412 - mae: 0.8098 - val_loss: 1.4483 - val_mae: 0.9496
# Epoch 190/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0769 - mae: 0.8337 - val_loss: 1.1412 - val_mae: 0.8930
# Epoch 191/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0620 - mae: 0.8241 - val_loss: 1.1313 - val_mae: 0.8786
# Epoch 192/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0822 - mae: 0.8345 - val_loss: 1.3654 - val_mae: 0.9747
# Epoch 193/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0537 - mae: 0.8218 - val_loss: 1.4814 - val_mae: 1.0111
# Epoch 194/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0841 - mae: 0.8457 - val_loss: 1.1401 - val_mae: 0.8935
# Epoch 195/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0461 - mae: 0.8149 - val_loss: 1.1339 - val_mae: 0.8650
# Epoch 196/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0913 - mae: 0.8359 - val_loss: 1.1794 - val_mae: 0.8684
# Epoch 197/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.1093 - mae: 0.8438 - val_loss: 1.1169 - val_mae: 0.8691
# Epoch 198/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0512 - mae: 0.8197 - val_loss: 1.1663 - val_mae: 0.8685
# Epoch 199/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0652 - mae: 0.8162 - val_loss: 1.5890 - val_mae: 1.0437
# Epoch 200/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0901 - mae: 0.8272 - val_loss: 1.1390 - val_mae: 0.8896
# Epoch 201/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0710 - mae: 0.8268 - val_loss: 1.6380 - val_mae: 1.0633
# Epoch 202/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0698 - mae: 0.8151 - val_loss: 1.1199 - val_mae: 0.8816
# Epoch 203/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0616 - mae: 0.8223 - val_loss: 1.2006 - val_mae: 0.9174
# Epoch 204/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0857 - mae: 0.8312 - val_loss: 1.1843 - val_mae: 0.9178
# Epoch 205/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0717 - mae: 0.8300 - val_loss: 1.2633 - val_mae: 0.9370
# Epoch 206/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0600 - mae: 0.8248 - val_loss: 1.1302 - val_mae: 0.8904
# Epoch 207/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0706 - mae: 0.8319 - val_loss: 1.2753 - val_mae: 0.9396
# Epoch 208/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0655 - mae: 0.8271 - val_loss: 1.1166 - val_mae: 0.8743
# Epoch 209/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0599 - mae: 0.8227 - val_loss: 1.2651 - val_mae: 0.8888
# Epoch 210/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0704 - mae: 0.8221 - val_loss: 1.1111 - val_mae: 0.8648
# Epoch 211/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0629 - mae: 0.8115 - val_loss: 1.1925 - val_mae: 0.8684
# Epoch 212/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.
1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0543 - mae: 0.8224 - val_loss: 1.1093 - val_mae: 0.8596
# Epoch 246/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0161 - mae: 0.8050 - val_loss: 1.3862 - val_mae: 0.9759
# Epoch 247/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0548 - mae: 0.8316 - val_loss: 1.1210 - val_mae: 0.8816
# Epoch 248/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0744 - mae: 0.8342 - val_loss: 1.1146 - val_mae: 0.8791
# Epoch 249/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0845 - mae: 0.8216 - val_loss: 1.1054 - val_mae: 0.8692
# Epoch 250/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0541 - mae: 0.8179 - val_loss: 1.1270 - val_mae: 0.8834
# Epoch 251/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0670 - mae: 0.8267 - val_loss: 1.2330 - val_mae: 0.8771
# Epoch 252/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0421 - mae: 0.8181 - val_loss: 1.1044 - val_mae: 0.8697
# Epoch 253/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0600 - mae: 0.8192 - val_loss: 1.2840 - val_mae: 0.9439
# Epoch 254/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0759 - mae: 0.8231 - val_loss: 1.3860 - val_mae: 0.9226
# Epoch 255/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0612 - mae: 0.8244 - val_loss: 1.1248 - val_mae: 0.8599
# Epoch 256/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0419 - mae: 0.8221 - val_loss: 1.2167 - val_mae: 0.9167
# Epoch 257/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0444 - mae: 0.8125 - val_loss: 1.0970 - val_mae: 0.8596
# Epoch 258/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0476 - mae: 0.8191 - val_loss: 1.0982 - val_mae: 0.8676
# Epoch 259/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0836 - mae: 0.8356 - val_loss: 1.1027 - val_mae: 0.8731
# Epoch 260/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0274 - mae: 0.8160 - val_loss: 1.1079 - val_mae: 0.8617
# Epoch 261/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0561 - mae: 0.8274 - val_loss: 1.1021 - val_mae: 0.8707
# Epoch 262/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0737 - mae: 0.8299 - val_loss: 1.2288 - val_mae: 0.9258
# Epoch 263/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0913 - mae: 0.8413 - val_loss: 1.0969 - val_mae: 0.8676
# Epoch 264/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0515 - mae: 0.8250 - val_loss: 1.1966 - val_mae: 0.8742
# Epoch 265/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0923 - mae: 0.8309 - val_loss: 1.2719 - val_mae: 0.9366
# Epoch 266/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0714 - mae: 0.8296 - val_loss: 1.1420 - val_mae: 0.8568
# Epoch 267/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0300 - mae: 0.8115 - val_loss: 1.1695 - val_mae: 0.9067
# Epoch 268/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0209 - mae: 0.8061 - val_loss: 1.1240 - val_mae: 0.8806
# Epoch 269/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0713 - mae: 0.8366 - val_loss: 1.0969 - val_mae: 0.8655
# Epoch 270/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0620 - mae: 0.8249 - val_loss: 1.0878 - val_mae: 0.8583
# Epoch 271/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0522 - mae: 0.8217 - val_loss: 1.1758 - val_mae: 0.9049
# Epoch 272/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0517 - mae: 0.8146 - val_loss: 1.3709 - val_mae: 0.9209
# Epoch 273/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0359 - mae: 0.8154 - val_loss: 2.1873 - val_mae: 1.2160
# Epoch 274/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0627 - mae: 0.8296 - val_loss: 1.1156 - val_mae: 0.8799
# Epoch 275/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0514 - mae: 0.8248 - val_loss: 1.1960 - val_mae: 0.8685
# Epoch 276/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0731 - mae: 0.8229 - val_loss: 1.1173 - val_mae: 0.8811
# Epoch 277/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0420 - mae: 0.8158 - val_loss: 1.4999 - val_mae: 1.0128
# Epoch 278/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.
1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0769 - mae: 0.8291 - val_loss: 1.1378 - val_mae: 0.8569
# Epoch 345/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0443 - mae: 0.8180 - val_loss: 1.1940 - val_mae: 0.9102
# Epoch 346/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0734 - mae: 0.8320 - val_loss: 1.0934 - val_mae: 0.8667
# Epoch 347/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0526 - mae: 0.8271 - val_loss: 1.1241 - val_mae: 0.8924
# Epoch 348/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0449 - mae: 0.8178 - val_loss: 1.1144 - val_mae: 0.8547
# Epoch 349/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0662 - mae: 0.8196 - val_loss: 1.1040 - val_mae: 0.8690
# Epoch 350/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0538 - mae: 0.8218 - val_loss: 1.1047 - val_mae: 0.8521
# Epoch 351/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0312 - mae: 0.8144 - val_loss: 1.1143 - val_mae: 0.8817
# Epoch 352/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0513 - mae: 0.8192 - val_loss: 1.0846 - val_mae: 0.8623
# Epoch 353/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0543 - mae: 0.8224 - val_loss: 1.4616 - val_mae: 1.0063
# Epoch 354/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0378 - mae: 0.8231 - val_loss: 1.0789 - val_mae: 0.8605
# Epoch 355/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0454 - mae: 0.8176 - val_loss: 1.5292 - val_mae: 1.0228
# Epoch 356/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0305 - mae: 0.8191 - val_loss: 1.2821 - val_mae: 0.9441
# Epoch 357/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0485 - mae: 0.8145 - val_loss: 1.1464 - val_mae: 0.8588
# Epoch 358/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0683 - mae: 0.8253 - val_loss: 1.3856 - val_mae: 0.9213
# ...
# Epoch 882/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0264 - mae: 0.8113 - val_loss: 1.1579 - val_mae: 0.9052
# Epoch 883/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0609 - mae: 0.8279 - val_loss: 1.0876 - val_mae: 0.8759
# Epoch 884/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0022 - mae: 0.8015 - val_loss: 1.3473 - val_mae: 0.9669
# Epoch 885/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0082 - mae: 0.8164 - val_loss: 1.3679 - val_mae: 0.9176
# Epoch 886/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0447 - mae: 0.8220 - val_loss: 1.2259 - val_mae: 0.8776
# Epoch 887/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0139 - mae: 0.8077 - val_loss: 1.2583 - val_mae: 0.8826
# Epoch 888/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0481 - mae: 0.8233 - val_loss: 1.1079 - val_mae: 0.8521
# Epoch 889/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0124 - mae: 0.8107 - val_loss: 1.0974 - val_mae: 0.8471
# Epoch 890/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0473 - mae: 0.8209 - val_loss: 1.0697 - val_mae: 0.8479
# Epoch 891/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0244 - mae: 0.8022 - val_loss: 1.0884 - val_mae: 0.8783
# Epoch 892/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0350 - mae: 0.8167 - val_loss: 1.2772 - val_mae: 0.9433
# Epoch 893/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0069 - mae: 0.8122 - val_loss: 1.2412 - val_mae: 0.9307
# Epoch 894/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0094 - mae: 0.7958 - val_loss: 1.1754 - val_mae: 0.9015
# Epoch 895/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0513 - mae: 0.8230 - val_loss: 1.0707 - val_mae: 0.8629
# Epoch 896/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0194 - mae: 0.8096 - val_loss: 1.3536 - val_mae: 0.9133
# Epoch 897/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0404 - mae: 0.8226 - val_loss: 1.0769 - val_mae: 0.8578
# Epoch 898/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0424 - mae: 0.8125 - val_loss: 1.0642 - val_mae: 0.8579
# Epoch 899/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0105 - mae: 0.8135 - val_loss: 1.2103 - val_mae: 0.8731
# Epoch 900/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0115 - mae: 0.8002 - val_loss: 1.7994 - val_mae: 1.1119
# Epoch 901/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.
1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0237 - mae: 0.8121 - val_loss: 1.0828 - val_mae: 0.8723
# Epoch 935/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0387 - mae: 0.8130 - val_loss: 1.1701 - val_mae: 0.8630
# Epoch 936/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0435 - mae: 0.8187 - val_loss: 1.1153 - val_mae: 0.8894
# Epoch 937/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0219 - mae: 0.8113 - val_loss: 1.3500 - val_mae: 0.9730
# Epoch 938/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0494 - mae: 0.8217 - val_loss: 1.0665 - val_mae: 0.8590
# Epoch 939/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0602 - mae: 0.8201 - val_loss: 1.1552 - val_mae: 0.8989
# Epoch 940/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0438 - mae: 0.8298 - val_loss: 1.0882 - val_mae: 0.8751
# Epoch 941/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0388 - mae: 0.8092 - val_loss: 1.1469 - val_mae: 0.8544
# Epoch 942/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0390 - mae: 0.8133 - val_loss: 1.0799 - val_mae: 0.8677
# Epoch 943/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0239 - mae: 0.8056 - val_loss: 1.0713 - val_mae: 0.8580
# Epoch 944/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0275 - mae: 0.8188 - val_loss: 1.2019 - val_mae: 0.8683
# Epoch 945/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0523 - mae: 0.8187 - val_loss: 1.0847 - val_mae: 0.8717
# Epoch 946/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0395 - mae: 0.8190 - val_loss: 1.1006 - val_mae: 0.8817
# Epoch 947/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0457 - mae: 0.8158 - val_loss: 1.3008 - val_mae: 0.9538
# Epoch 948/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0067 - mae: 0.8039 - val_loss: 1.1383 - val_mae: 0.8562
# Epoch 949/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0472 - mae: 0.8157 - val_loss: 1.0669 - val_mae: 0.8549
# Epoch 950/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0115 - mae: 0.8068 - val_loss: 1.4867 - val_mae: 1.0093
# Epoch 951/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0553 - mae: 0.8223 - val_loss: 1.2796 - val_mae: 0.9484
# Epoch 952/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0084 - mae: 0.8035 - val_loss: 1.0892 - val_mae: 0.8463
# Epoch 953/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0152 - mae: 0.8170 - val_loss: 1.2671 - val_mae: 0.9460
# Epoch 954/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0496 - mae: 0.8202 - val_loss: 1.1054 - val_mae: 0.8533
# Epoch 955/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0469 - mae: 0.8264 - val_loss: 1.1915 - val_mae: 0.8665
# Epoch 956/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0423 - mae: 0.8239 - val_loss: 1.1523 - val_mae: 0.8999
# Epoch 957/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0526 - mae: 0.8272 - val_loss: 1.0794 - val_mae: 0.8711
# Epoch 958/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0298 - mae: 0.8112 - val_loss: 1.2860 - val_mae: 0.8908
# Epoch 959/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0580 - mae: 0.8256 - val_loss: 1.1163 - val_mae: 0.8508
# Epoch 960/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0725 - mae: 0.8244 - val_loss: 1.1044 - val_mae: 0.8852
# Epoch 961/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0145 - mae: 0.8132 - val_loss: 1.0736 - val_mae: 0.8666
# Epoch 962/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0283 - mae: 0.8150 - val_loss: 1.1977 - val_mae: 0.9168
# Epoch 963/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0198 - mae: 0.8167 - val_loss: 1.1585 - val_mae: 0.9054
# Epoch 964/1000
# 38/38 [==============================] - 0s 3ms/step - loss: 1.0470 - mae: 0.8236 - val_loss: 1.0701 - val_mae: 0.8600
# Epoch 965/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0289 - mae: 0.8119 - val_loss: 1.1680 - val_mae: 0.9105
# Epoch 966/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0183 - mae: 0.8066 - val_loss: 1.3473 - val_mae: 0.9120
# Epoch 967/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0548 - mae: 0.8212 - val_loss: 1.0721 - val_mae: 0.8611
# Epoch 968/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0157 - mae: 0.8060 - val_loss: 1.1712 - val_mae: 0.8641
# Epoch 969/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0196 - mae: 0.8100 - val_loss: 1.1077 - val_mae: 0.8491
# Epoch 970/1000
# 38/38 [==============================] - 0s 6ms/step - loss: 1.0228 - mae: 0.8191 - val_loss: 1.1788 - val_mae: 0.9099
# Epoch 971/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0544 - mae: 0.8222 - val_loss: 1.2685 - val_mae: 0.9373
# Epoch 972/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0248 - mae: 0.8173 - val_loss: 1.0631 - val_mae: 0.8546
# Epoch 973/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0460 - mae: 0.8222 - val_loss: 1.0766 - val_mae: 0.8688
# Epoch 974/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0355 - mae: 0.8092 - val_loss: 1.2512 - val_mae: 0.8819
# Epoch 975/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0469 - mae: 0.8146 - val_loss: 1.0728 - val_mae: 0.8520
# Epoch 976/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0228 - mae: 0.8093 - val_loss: 1.0787 - val_mae: 0.8482
# Epoch 977/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0750 - mae: 0.8200 - val_loss: 1.1961 - val_mae: 0.8704
# Epoch 978/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0209 - mae: 0.8108 - val_loss: 1.1677 - val_mae: 0.8627
# Epoch 979/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0325 - mae: 0.8106 - val_loss: 1.1159 - val_mae: 0.8891
# Epoch 980/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0153 - mae: 0.8033 - val_loss: 1.2754 - val_mae: 0.9359
# Epoch 981/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0403 - mae: 0.8171 - val_loss: 1.8859 - val_mae: 1.1327
# Epoch 982/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0398 - mae: 0.8248 - val_loss: 1.4344 - val_mae: 0.9954
# Epoch 983/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0275 - mae: 0.8070 - val_loss: 1.3885 - val_mae: 0.9265
# Epoch 984/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0118 - mae: 0.8048 - val_loss: 1.0785 - val_mae: 0.8537
# Epoch 985/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0354 - mae: 0.8149 - val_loss: 1.2492 - val_mae: 0.9325
# Epoch 986/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0512 - mae: 0.8189 - val_loss: 1.1993 - val_mae: 0.8701
# Epoch 987/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0125 - mae: 0.8101 - val_loss: 1.1781 - val_mae: 0.9091
# Epoch 988/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0497 - mae: 0.8223 - val_loss: 1.3371 - val_mae: 0.9673
# Epoch 989/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0668 - mae: 0.8173 - val_loss: 1.0886 - val_mae: 0.8524
# Epoch 990/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0270 - mae: 0.8226 - val_loss: 1.0677 - val_mae: 0.8607
# Epoch 991/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0277 - mae: 0.8101 - val_loss: 1.0782 - val_mae: 0.8718
# Epoch 992/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0428 - mae: 0.8242 - val_loss: 1.4165 - val_mae: 0.9339
# Epoch 993/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0529 - mae: 0.8199 - val_loss: 1.0898 - val_mae: 0.8758
# Epoch 994/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0186 - mae: 0.8084 - val_loss: 1.1981 - val_mae: 0.8699
# Epoch 995/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0167 - mae: 0.8131 - val_loss: 1.0721 - val_mae: 0.8468
# Epoch 996/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0660 - mae: 0.8179 - val_loss: 1.2586 - val_mae: 0.9360
# Epoch 997/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0456 - mae: 0.8234 - val_loss: 1.1252 - val_mae: 0.8538
# Epoch 998/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0514 - mae: 0.8079 - val_loss: 1.0598 - val_mae: 0.8543
# Epoch 999/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0419 - mae: 0.8240 - val_loss: 1.2630 - val_mae: 0.8843
# Epoch 1000/1000
# 38/38 [==============================] - 0s 2ms/step - loss: 1.0240 - mae: 0.8152 - val_loss: 1.1274 - val_mae: 0.8907
# Done!

# %% [markdown]
# ## Convert the Tensorflow Model to Tensorflow Lite Model

# %%
# Convert the model to the TensorFlow Lite format with quantization
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()
open("model.tflite", "wb").write(tflite_model)
# Out:
# 2532

# %% [markdown]
# ## Predict

# %% [markdown]
# ### Predict with Tensorflow Model

# %%
# Use the model to make predictions from our test data

############################################################
#@markdown How to use the model to predict the result with the test data (`x_test`) and save the result in a variable `predictions`?
script = "predictions =model.predict(x_test)" #@param {type:"string"}
exec(script)
############################################################

# %% [markdown]
# ### Predict with Tensorflow Lite Model

# %%
# Use the Tensorflow lite model to make interfences from our test data
#@markdown Please choose and fill in correct code statements from one of the following:
#@markdown 1. interpreter.invoke() 
#@markdown 2. interpreter_input().fill(x_test[i])
#@markdown 3. interpreter = tf.lite.Interpreter('model.tflite')
#@markdown 4. interpreter_predictions[i] = interpreter_output()[0]
#@markdown 5. interpreter_output = interpreter.tensor(interpreter.get_output_details()[0]["index"])
#@markdown 6. interpreter_input = interpreter.tensor(interpreter.get_input_details()[0]["index"])

############################################################
# Instantiate an interpreter for the TFLite model
#@markdown Which is the statement to instantiate an interpreter with a TFLite Model named `model.tflite`?
script_1 = "interpreter = tf.lite.Interpreter('model.tflite')" #@param {type:"string"}
exec(script_1)
############################################################

# Allocate memory for the model
interpreter.allocate_tensors()

############################################################
# Get the input tensors so we can feed in values 
#@markdown Which is the statement to get input sensors?
script_2 = "interpreter_input = interpreter.tensor(interpreter.get_input_details()[0][\"index\"])" #@param {type:"string"}
exec(script_2)
############################################################

############################################################
# Get the output tensors so we can get the results
#@markdown Which is the statement to get output sensors?
script_3 = "interpreter_output = interpreter.tensor(interpreter.get_output_details()[0][\"index\"])" #@param {type:"string"}
exec(script_3)
############################################################

# Create arrays to store the results
interpreter_predictions = np.empty(x_test.size)

# Run each model's interpreter for each value and store the results in arrays
for i in range(x_test.size):
  ############################################################
  #@markdown Which is the statement to fill the input of the interpreter with `x_test[i]`?
  script_4 = "interpreter_input().fill(x_test[i])" #@param {type:"string"}
  exec(script_4)
  ############################################################
  ############################################################
  #@markdown Which is the statement to invoke the interpreter?
  script_5 = "interpreter.invoke()" #@param {type:"string"}
  exec(script_5)
  ############################################################
  ############################################################
  #@markdown Which is the statement to get the output from the interpreter and save the output in `interpreter_predictions[i]`?
  script_6 = "interpreter_predictions[i] = interpreter_output()[0]"#@param {type:"string"}
  exec(script_6)
  ############################################################


# Make the shape of the y_test be the same as the predictions
y_test = np.reshape(y_test, predictions.shape)
# Make the shape of the interpreter_predictions be the same as the predictions
interpreter_predictions = np.reshape(interpreter_predictions, predictions.shape)

# %% [markdown]
# ## Plot the Result

# %%
plt.clf()
plt.title('Test data predicted vs actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Predicted (tensorflow)')
############################################################
#@markdown Please write the statement to plot the outputs in green dots with a label `Predicted (tflite)` from the interpreter.
script = "plt.plot(x_test, interpreter_predictions, 'g.', label='Predicted (tflite)')"#@param {type:"string"}
exec(script)
############################################################
plt.legend()
plt.show()
